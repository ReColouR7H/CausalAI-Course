# %% [markdown]
# ## 1. Fitting polinomial predictors to data

# %%
install.packages("ggplot2")
# Out:
# Installing package into 'C:/Users/User/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
#
# also installing the dependencies 'farver', 'labeling', 'R6', 'RColorBrewer', 'viridisLite', 'magrittr', 'pkgconfig', 'gtable', 'isoband', 'scales', 'tibble', 'withr'
# package 'farver' successfully unpacked and MD5 sums checked
# package 'labeling' successfully unpacked and MD5 sums checked
# package 'R6' successfully unpacked and MD5 sums checked
# package 'RColorBrewer' successfully unpacked and MD5 sums checked
# package 'viridisLite' successfully unpacked and MD5 sums checked
# package 'magrittr' successfully unpacked and MD5 sums checked
# package 'pkgconfig' successfully unpacked and MD5 sums checked
# package 'gtable' successfully unpacked and MD5 sums checked
# package 'isoband' successfully unpacked and MD5 sums checked
# package 'scales' successfully unpacked and MD5 sums checked
# package 'tibble' successfully unpacked and MD5 sums checked
# package 'withr' successfully unpacked and MD5 sums checked
# package 'ggplot2' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\User\AppData\Local\Temp\Rtmp8QmoWB\downloaded_packages

# %%
install.packages("caTools")
# Out:
# Installing package into 'C:/Users/User/AppData/Local/R/win-library/4.5'
# (as 'lib' is unspecified)
#
# also installing the dependency 'bitops'
# package 'bitops' successfully unpacked and MD5 sums checked
# package 'caTools' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\User\AppData\Local\Temp\Rtmp8QmoWB\downloaded_packages

# %%
library(ggplot2)
library(caTools)

# %% [markdown]
# ### Let's repeat the excercise but in R noting the diferences in coding. Notice that the results might slightly vary due to the fact that we did not specify a seed.

# %% [markdown]
# ### First, we generate the feature

# %% [markdown]
# W <- runif(1000,0,1)
# W <- sort(W)
# print(W)
#
# #### Then, the noise

# %%
e <- rnorm(1000,0,1)
print(e)
# Out:
#    [1]  0.5329023500  0.1032467694 -0.7672358269 -0.3329589511 -0.5221288643
#    [6] -0.6295292580  0.7128388364  1.5597558386 -0.7277881861  1.2571532061
#   [11]  0.1744088959 -0.4271947654 -0.7571229152 -0.3287472511  1.0259021758
#   [16]  0.8152232313  1.3659210351  1.2952785628  0.9694264248  0.6127261896
#   [21]  0.4058739138 -0.0472184842  0.5821170133 -0.8605913231 -1.1920601457
#   [26] -0.2697147540  0.0666712797  0.4995272323 -0.4924185583 -0.3911646163
#   [31] -1.2288815558 -1.4527241820  2.3054561525  0.5321009202 -0.1094067542
#   [36]  0.0008108149 -1.0335592456 -1.1927142638 -1.3404840843  0.3451116526
#   [41] -1.4515648036 -0.6610296924 -1.8862069687  0.4134512261  1.0710338321
#   [46] -0.2855407979 -0.6974896517  0.0829545990  2.1193026933 -0.4513382456
#   [51] -0.4481742854  1.2209348111  2.0210296202 -0.1848274579  0.2253500860
#   [56] -1.3973762706  1.6643286115 -0.9992113649 -0.1444434448  1.8027060638
#   [61]  0.6550646923 -0.8242137455  0.7309373764 -0.4393212024  0.9170447798
#   [66] -0.9262698794  0.3756516997 -0.8593922459  0.4752181005  0.4095150508
#   [71] -2.0566220884 -0.9793373466  0.2817108282 -0.0157323905 -0.0647107251
#   [76]  0.2376301207  0.6203370315  0.4286182516  0.4682741240 -0.2062330987
#  [966]  0.1355438771  0.1984704794  0.1739990542  0.5643247310  1.9119745023
#  [971] -1.3730387618 -0.4631463852 -0.8416629430  1.5336238895  1.9894952218
#  [976]  0.3700027413  1.2755986376 -1.3635119529  1.7765475342  0.1655546384
#  [981] -1.6339840772 -1.8023002158  0.5856732203  1.1056652566  2.0480288322
#  [986] -1.5515990961 -0.7752460411 -0.0506812639  0.7439185447 -1.0394816575
#  [991]  0.4946790517 -0.9645983608 -0.3612308854  0.4919958495  1.0004714910
#  [996]  0.1614922926 -0.0219823651  0.2095818631  1.6936309753  1.6124484051

# %% [markdown]
# ### And finally, the dependent variable

# %%
y <- exp(4*W) + e

# %% [markdown]
# ### Estimation is similar to Python. We use a function called "lm" to fit a linear model

# %%
model <- lm(y~W)
y_hat <- model$fitted.values

# %% [markdown]
# ### To plot in R, we can use base R plot functions or ggplot2, as we do here. ggplot2 tends to be a better option to plot complex graph. As in Python, we create a figure where we will plot all the lines, dots, etc.

# %%
ggplot()+
geom_point(data= data.frame(W,y), aes(x=W,y=y), color = 'blue')+
geom_line(data= data.frame(W,y_hat), aes(x=W,y=y_hat), size = 1, color = 'red')+
ggtitle("p=2")
# Out:
# Warning message:
# "Using `size` aesthetic for lines was deprecated in ggplot2 3.4.0.
# ℹ Please use `linewidth` instead."
# plot without title

# %% [markdown]
# ### Now, let's fit a cuadratic predictor. We can create a dataframe to store all the variables

# %%
data <- data.frame(y,W,W^2)
data
# Out:
#      y          W            W.2
# 1     1.5356557 0.0006873973 4.725151e-07
# 2     1.1085053 0.0013111986 1.719242e-06
# 3     0.2403534 0.0018901485 3.572661e-06
# 4     0.6748006 0.0019324031 3.734182e-06
# 5     0.4900499 0.0030262938 9.158454e-06
# 6     0.3841230 0.0033899820 1.149198e-05
# 7     1.7307527 0.0044388219 1.970314e-05
# 8     2.5820046 0.0055012179 3.026340e-05
# 9     0.2976868 0.0062889850 3.955133e-05
# 10    2.2852926 0.0069376943 4.813160e-05
# 11    1.2057683 0.0077194339 5.958966e-05
# 12    0.6052586 0.0079844797 6.375192e-05
# 13    0.2755155 0.0080292674 6.446914e-05
# 14    0.7099537 0.0094927130 9.011160e-05
# 15    2.0688064 0.0105023396 1.102991e-04
# 16    1.8584729 0.0105851213 1.120448e-04
# 17    2.4096523 0.0107005164 1.145011e-04
# 18    2.3443242 0.0119702162 1.432861e-04
# 19    2.0208617 0.0125390487 1.572277e-04
# 20    1.6762164 0.0153890350 2.368224e-04
# 21    1.4728004 0.0161955224 2.622949e-04
# 22    1.0290807 0.0183821106 3.379020e-04
# 23    1.6629060 0.0194228354 3.772465e-04
# 24    0.2218547 0.0198058269 3.922708e-04
# 25   -0.1063825 0.0205510834 4.223470e-04
# 26    0.8194219 0.0213463304 4.556658e-04
# 27    1.1732199 0.0253114603 6.406700e-04
# 28    1.6084580 0.0258490585 6.681738e-04
# 29    0.6171952 0.0260029887 6.761554e-04
# 30    0.7253109 0.0275442153 7.586838e-04
# ⋮    ⋮          ⋮            ⋮
# 971  47.17483   0.9706376    0.9421373
# 972  48.12344   0.9708369    0.9425242
# 973  47.83100   0.9712794    0.9433836
# 974  50.27432   0.9716286    0.9440621
# 975  50.82369   0.9721077    0.9449934
# 976  49.30188   0.9726073    0.9459649
# 977  50.50759   0.9741359    0.9489407
# 978  48.04342   0.9750227    0.9506692
# 979  51.29592   0.9755910    0.9517778
# 980  49.73132   0.9758251    0.9522347
# 981  48.02361   0.9762878    0.9531379
# 982  48.20553   0.9780449    0.9565718
# 983  50.60489   0.9781018    0.9566832
# 984  51.20438   0.9784988    0.9574599
# 985  52.15246   0.9785273    0.9575158
# 986  49.04539   0.9809730    0.9623081
# 987  51.25578   0.9879600    0.9760650
# 988  52.20332   0.9890291    0.9781786
# 989  53.11200   0.9895743    0.9792573
# 990  51.43707   0.9900916    0.9802814
# 991  53.09583   0.9906845    0.9814558
# 992  51.74853   0.9912161    0.9825094
# 993  52.47607   0.9918043    0.9836758
# 994  53.38831   0.9920834    0.9842295
# 995  54.36144   0.9942699    0.9885726
# 996  53.52604   0.9942866    0.9886059
# 997  53.46818   0.9948745    0.9897752
# 998  54.23029   0.9973419    0.9946908
# 999  56.19053   0.9995359    0.9990721
# 1000 56.12289   0.9995981    0.9991963

# %% [markdown]
# ### To fit the model, we now need to specify the dataset in the "data" argument. Notice that, eventhough the model is non linear in features, it is still linear in parameters, so the "lm" function is appropriate.

# %%
model <- lm(y~W + W.2, data= data)
y_hat <- model$fitted.values

# %% [markdown]
# ### And we can plot the fit of the cuadratic predictor

# %%
ggplot()+
geom_point(data= data.frame(W,y), aes(x=W,y=y), color = 'blue')+
geom_line(data= data.frame(W,y_hat), aes(x=W,y=y_hat), size = 1, color = 'red')+
ggtitle("p=3")
# Out:
# plot without title

# %% [markdown]
# ### Finally, we fit the cubic predictor to the data

# %%
data <- data.frame(y,W,W^2,W^3)
data
# Out:
#      y          W            W.2          W.3
# 1     1.5356557 0.0006873973 4.725151e-07 3.248056e-10
# 2     1.1085053 0.0013111986 1.719242e-06 2.254267e-09
# 3     0.2403534 0.0018901485 3.572661e-06 6.752861e-09
# 4     0.6748006 0.0019324031 3.734182e-06 7.215944e-09
# 5     0.4900499 0.0030262938 9.158454e-06 2.771617e-08
# 6     0.3841230 0.0033899820 1.149198e-05 3.895760e-08
# 7     1.7307527 0.0044388219 1.970314e-05 8.745873e-08
# 8     2.5820046 0.0055012179 3.026340e-05 1.664855e-07
# 9     0.2976868 0.0062889850 3.955133e-05 2.487377e-07
# 10    2.2852926 0.0069376943 4.813160e-05 3.339223e-07
# 11    1.2057683 0.0077194339 5.958966e-05 4.599984e-07
# 12    0.6052586 0.0079844797 6.375192e-05 5.090259e-07
# 13    0.2755155 0.0080292674 6.446914e-05 5.176399e-07
# 14    0.7099537 0.0094927130 9.011160e-05 8.554036e-07
# 15    2.0688064 0.0105023396 1.102991e-04 1.158399e-06
# 16    1.8584729 0.0105851213 1.120448e-04 1.186008e-06
# 17    2.4096523 0.0107005164 1.145011e-04 1.225220e-06
# 18    2.3443242 0.0119702162 1.432861e-04 1.715165e-06
# 19    2.0208617 0.0125390487 1.572277e-04 1.971486e-06
# 20    1.6762164 0.0153890350 2.368224e-04 3.644468e-06
# 21    1.4728004 0.0161955224 2.622949e-04 4.248004e-06
# 22    1.0290807 0.0183821106 3.379020e-04 6.211352e-06
# 23    1.6629060 0.0194228354 3.772465e-04 7.327197e-06
# 24    0.2218547 0.0198058269 3.922708e-04 7.769247e-06
# 25   -0.1063825 0.0205510834 4.223470e-04 8.679689e-06
# 26    0.8194219 0.0213463304 4.556658e-04 9.726793e-06
# 27    1.1732199 0.0253114603 6.406700e-04 1.621629e-05
# 28    1.6084580 0.0258490585 6.681738e-04 1.727166e-05
# 29    0.6171952 0.0260029887 6.761554e-04 1.758206e-05
# 30    0.7253109 0.0275442153 7.586838e-04 2.089735e-05
# ⋮    ⋮          ⋮            ⋮            ⋮
# 971  47.17483   0.9706376    0.9421373    0.9144739
# 972  48.12344   0.9708369    0.9425242    0.9150373
# 973  47.83100   0.9712794    0.9433836    0.9162891
# 974  50.27432   0.9716286    0.9440621    0.9172777
# 975  50.82369   0.9721077    0.9449934    0.9186353
# 976  49.30188   0.9726073    0.9459649    0.9200524
# 977  50.50759   0.9741359    0.9489407    0.9243972
# 978  48.04342   0.9750227    0.9506692    0.9269241
# 979  51.29592   0.9755910    0.9517778    0.9285458
# 980  49.73132   0.9758251    0.9522347    0.9292145
# 981  48.02361   0.9762878    0.9531379    0.9305369
# 982  48.20553   0.9780449    0.9565718    0.9355702
# 983  50.60489   0.9781018    0.9566832    0.9357336
# 984  51.20438   0.9784988    0.9574599    0.9368734
# 985  52.15246   0.9785273    0.9575158    0.9369553
# 986  49.04539   0.9809730    0.9623081    0.9439983
# 987  51.25578   0.9879600    0.9760650    0.9643133
# 988  52.20332   0.9890291    0.9781786    0.9674471
# 989  53.11200   0.9895743    0.9792573    0.9690479
# 990  51.43707   0.9900916    0.9802814    0.9705684
# 991  53.09583   0.9906845    0.9814558    0.9723131
# 992  51.74853   0.9912161    0.9825094    0.9738792
# 993  52.47607   0.9918043    0.9836758    0.9756140
# 994  53.38831   0.9920834    0.9842295    0.9764377
# 995  54.36144   0.9942699    0.9885726    0.9829080
# 996  53.52604   0.9942866    0.9886059    0.9829576
# 997  53.46818   0.9948745    0.9897752    0.9847020
# 998  54.23029   0.9973419    0.9946908    0.9920468
# 999  56.19053   0.9995359    0.9990721    0.9986085
# 1000 56.12289   0.9995981    0.9991963    0.9987947

# %%
model <- lm(y~W + W.2 + W.3, data= data)
y_hat <- model$fitted.values

# %% [markdown]
# ## And plot the results

# %%
ggplot()+
geom_point(data= data.frame(W,y), aes(x=W,y=y), color = 'blue')+
geom_line(data= data.frame(W,y_hat), aes(x=W,y=y_hat), size = 1, color = 'red')+
ggtitle("p=4")
# Out:
# plot without title

# %% [markdown]
# ## 2. Overfitting

# %% [markdown]
# ### Now, in the overfitting section, we construct the random matrix/vector to fit a linear model. As we did in Python, we start with $p=n=1000$

# %%
X <- matrix(rnorm(1000*(1000-1), 0, 1), nrow =1000, ncol = 1000-1 )
y <- rnorm(1000, 0, 1)

data <- data.frame(y,X)
dim(data)
dim(X)
# Out:
# [1] 1000 1000
# [1] 1000  999

# %% [markdown]
# ### We fit the model and calculate de MSE

# %%
model <- lm(y~., data= data)
mse <- mean((y - model$fitted.values)^2)
mse
# Out:
# [1] 0

# %% [markdown]
# ## and the R-squared

# %%
R_sq <- 1 - mse/mean((y - mean(y))^2)
R_sq
# Out:
# [1] 1

# %% [markdown]
# ### Now, we analyse the case where $p=\frac{n}{2}=500$. First we construct the data

# %%
X <- matrix(rnorm(1000*(500-1), 0, 1), nrow =1000, ncol = 500-1 )
data <- data.frame(y,X)
dim(data)
# Out:
# [1] 1000  500

# %% [markdown]
# ### Fit the model and calculate the MSE

# %%
model <- lm(y~., data= data)
mse <- mean((y - model$fitted.values)^2)
mse
# Out:
# [1] 0.5566333

# %% [markdown]
# ## Calculate the R-squared

# %%
R_sq <- 1 - mse/mean((y - mean(y))^2)
R_sq
# Out:
# [1] 0.4677073

# %% [markdown]
# ### And the adjusted R-squared

# %%
adj_mse <- 1000/500*mse
adjR_sq <- 1 - adj_mse/mean((y-mean(y))^2)
adjR_sq
# Out:
# [1] -0.06458546

# %% [markdown]
# ### Finally, we analyse the case where $p=\frac{n}{20}=50$

# %%
X <- matrix(rnorm(1000*(50-1), 0, 1), nrow =1000, ncol = 50-1 )
data <- data.frame(y,X)
dim(data)
# Out:
# [1] 1000   50

# %% [markdown]
# ### We fit the model and calculate the MSE

# %%
model <- lm(y~., data= data)
mse <- mean((y - model$fitted.values)^2)
mse
# Out:
# [1] 1.00959

# %% [markdown]
# ### Calculate the R-squared

# %%
R_sq <- 1 - mse/mean((y - mean(y))^2)
R_sq
# Out:
# [1] 0.03455716

# %% [markdown]
# ### And the adjusted R-squared

# %%
adj_mse <- 1000/500*mse
adjR_sq <- 1 - adj_mse/mean((y-mean(y))^2)
adjR_sq
# Out:
# [1] -0.9308857

# %% [markdown]
# ## 3. Data splitting

# %% [markdown]
# ### In the final section, we will split the sample of the same three predictors we worked with in Python and assess out of sample accuracy

# %% [markdown]
# ### To do that, we work with the data generating process of section 1

# %%
# Features

W <- runif(1000,0,1)
W <- sort(W)

# Noise

e <- rnorm(1000,0,1)

# Dependent variable

y <- exp(4*W) + e

# %% [markdown]
# ### Then, we create dataframes that store the variables of these models

# %%
data_1 <- data.frame(y,W)
data_2 <- data.frame(y,W,W^2)
data_3 <- data.frame(y,sin(W))

# %% [markdown]
# ### With the help of "caTools" package's function "sample.split", we can easily divide each sample into training and test sets.

# %%
sample_1 <- sample.split(data_1$y, SplitRatio = 0.75)
train_1 <- subset(data_1, sample_1 == TRUE)
test_1 <- subset(data_1, sample_1 == FALSE)

sample_2 <- sample.split(data_2$y, SplitRatio = 0.75)
train_2 <- subset(data_2, sample_2 == TRUE)
test_2 <- subset(data_2, sample_2 == FALSE)

sample_3 <- sample.split(data_3$y, SplitRatio = 0.75)
train_3 <- subset(data_3, sample_3 == TRUE)
test_3 <- subset(data_3, sample_3 == FALSE)

# %% [markdown]
# ### Now, we fit the models with the training set

# %%
model_1 <- lm(y~., data= train_1)
model_1
# Out:
# Call:
# lm(formula = y ~ ., data = train_1)
#
# Coefficients:
# (Intercept)            W
#      -8.295       43.290

# %%
model_2 <- lm(y~., data= train_2)
model_2
# Out:
# Call:
# lm(formula = y ~ ., data = train_2)
#
# Coefficients:
# (Intercept)            W          W.2
#       4.985      -35.857       79.206

# %%
model_3 <- lm(y~., data= train_3)
model_3
# Out:
# Call:
# lm(formula = y ~ ., data = train_3)
#
# Coefficients:
# (Intercept)       sin.W.
#       -8.66        48.18

# %% [markdown]
# ### And finally, we calculate out of sample goodness of fit.

# %%
y_1_test = test_1$y
y_2_test = test_2$y
y_3_test = test_3$y

# %%
y_1_hat_test = predict(model_1, test_1["W"])
y_2_hat_test = predict(model_2, test_2[c("W","W.2")])
y_3_hat_test = predict(model_3, test_3["sin.W."])

# %%
# MSE

mse_1_test = mean((y_1_test - y_1_hat_test)^2)
mse_2_test = mean((y_2_test - y_2_hat_test)^2)
mse_3_test = mean((y_3_test - y_3_hat_test)^2)

print(paste0("MSE out of sample of predictor 1 is ", mse_1_test))
print(paste0("MSE out of sample of predictor 2 is ", mse_2_test))
print(paste0("MSE out of sample of predictor 3 is ", mse_3_test))

R_sq_1_test = 1 - mse_1_test / mean((y_1_test-mean(y_1_test))^2)
R_sq_2_test = 1 - mse_2_test / mean((y_2_test-mean(y_2_test))^2)
R_sq_3_test = 1 - mse_3_test / mean((y_3_test-mean(y_3_test))^2)

print(paste0("R-squared out of sample of predictor 1 is ", R_sq_1_test))
print(paste0("R-squared out of sample of predictor 2 is ", R_sq_2_test))
print(paste0("R-squared out of sample of predictor 3 is ", R_sq_3_test))

adj_mse_1_test = 250 / (250-2) * mse_1_test
adjR_sq_1_test = 1 - adj_mse_1_test / mean((y_1_test-mean(y_1_test))^2)

adj_mse_2_test = 250 / (250-3) * mse_2_test
adjR_sq_2_test = 1 - adj_mse_2_test / mean((y_2_test-mean(y_2_test))^2)

adj_mse_3_test = 250 / (250-2) * mse_3_test
adjR_sq_3_test = 1 - adj_mse_3_test / mean((y_3_test-mean(y_3_test))^2)

print(paste0("Adjusted R-squared out of sample of predictor 1 is ", adjR_sq_1_test))
print(paste0("Adjusted R-squared out of sample of predictor 2 is ", adjR_sq_2_test))
print(paste0("Adjusted R-squared out of sample of predictor 3 is ", adjR_sq_3_test))
# Out:
# [1] "MSE out of sample of predictor 1 is 41.6252072994476"
# [1] "MSE out of sample of predictor 2 is 4.84847936907961"
# [1] "MSE out of sample of predictor 3 is 56.5303221072497"
# [1] "R-squared out of sample of predictor 1 is 0.809619475203929"
# [1] "R-squared out of sample of predictor 2 is 0.972020956402893"
# [1] "R-squared out of sample of predictor 3 is 0.736078318533747"
# [1] "Adjusted R-squared out of sample of predictor 1 is 0.808084148391058"
# [1] "Adjusted R-squared out of sample of predictor 2 is 0.971681129962442"
# [1] "Adjusted R-squared out of sample of predictor 3 is 0.733949917876761"
