# %%
#Add packages

using Pkg
Pkg.add("Plots")
Pkg.add("Random")
Pkg.add("GLM")
Pkg.add("DataFrames")
Pkg.add("LaTeXStrings")
Pkg.add("Statistics")  =#
# Out:
#     Updating registry at `C:\Users\User\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed GR_jll ─────────────────────── v0.73.17+0
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed x265_jll ───────────────────── v4.1.0+0
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed LoggingExtras ──────────────── v1.1.0
#    Installed Opus_jll ───────────────────── v1.5.2+0
#    Installed JpegTurbo_jll ──────────────── v3.1.2+0
#    Installed Libmount_jll ───────────────── v2.41.1+0
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Unitful ────────────────────── v1.24.0
#    Installed Measures ───────────────────── v0.3.2
#    Installed ConcurrentUtilities ────────── v2.5.0
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed Grisu ──────────────────────── v1.0.2
#    Installed Contour ────────────────────── v0.6.3
#    Installed Xorg_xcb_util_image_jll ────── v0.4.1+0
#    Installed RecipesPipeline ────────────── v0.6.12
#    Installed PlotUtils ──────────────────── v1.4.3
#    Installed DelimitedFiles ─────────────── v1.9.1
#    Installed OpenSSL ────────────────────── v1.5.0
#    Installed HTTP ───────────────────────── v1.10.17
#    Installed Xorg_libSM_jll ─────────────── v1.2.6+0
#    Installed Cairo_jll ──────────────────── v1.18.5+0
#    Installed Xorg_xcb_util_jll ──────────── v0.4.1+0
#    Installed Fontconfig_jll ─────────────── v2.17.1+0
#    Installed Xorg_libxkbfile_jll ────────── v1.1.3+0
#    Installed Statistics ─────────────────── v1.11.1
#    Installed Xorg_libXinerama_jll ───────── v1.1.6+0
#    Installed ColorSchemes ───────────────── v3.30.0
#    Installed GR ─────────────────────────── v0.73.17
#    Installed Xorg_libXau_jll ────────────── v1.0.13+0
#    Installed EpollShim_jll ──────────────── v0.0.20230411+1
#    Installed Pango_jll ──────────────────── v1.56.3+0
#    Installed IrrationalConstants ────────── v0.2.4
#    Installed Missings ───────────────────── v1.2.0
#    Installed PtrArrays ──────────────────── v1.3.0
#    Installed FFMPEG ─────────────────────── v0.4.4
#    Installed Showoff ────────────────────── v1.0.3
#    Installed xkbcommon_jll ──────────────── v1.9.2+0
#    Installed Xorg_xcb_util_keysyms_jll ──── v0.4.1+0
#    Installed Bzip2_jll ──────────────────── v1.0.9+0
#    Installed SimpleBufferStream ─────────── v1.2.0
#    Installed XZ_jll ─────────────────────── v5.8.1+0
#    Installed NaNMath ────────────────────── v1.1.3
#    Installed HarfBuzz_jll ───────────────── v8.5.1+0
#    Installed PlotThemes ─────────────────── v3.3.0
#    Installed LZO_jll ────────────────────── v2.10.3+0
#    Installed FriBidi_jll ────────────────── v1.0.17+0
#    Installed fzf_jll ────────────────────── v0.61.1+0
#    Installed UnicodeFun ─────────────────── v0.4.1
#    Installed x264_jll ───────────────────── v10164.0.1+0
#    Installed TranscodingStreams ─────────── v0.11.3
#    Installed GLFW_jll ───────────────────── v3.4.0+2
#    Installed MbedTLS ────────────────────── v1.1.9
#    Installed FreeType2_jll ──────────────── v2.13.4+0
#    Installed StatsAPI ───────────────────── v1.7.1
#    Installed Xorg_libxcb_jll ────────────── v1.17.1+0
#    Installed JLFzf ──────────────────────── v0.1.11
#    Installed libpng_jll ─────────────────── v1.6.50+0
#    Installed DataStructures ─────────────── v0.19.0
#    Installed CodecZlib ──────────────────── v0.7.8
#    Installed StatsBase ──────────────────── v0.34.6
#    Installed Colors ─────────────────────── v0.13.1
#    Installed mtdev_jll ──────────────────── v1.1.7+0
#    Installed ExceptionUnwrapping ────────── v0.1.11
#    Installed libaom_jll ─────────────────── v3.12.1+0
#    Installed Dbus_jll ───────────────────── v1.16.2+0
#    Installed ColorTypes ─────────────────── v0.12.1
#    Installed Scratch ────────────────────── v1.3.0
#    Installed Zstd_jll ───────────────────── v1.5.7+1
#    Installed eudev_jll ──────────────────── v3.2.14+0
#    Installed TensorCore ─────────────────── v0.1.1
#    Installed Xorg_libXext_jll ───────────── v1.3.7+0
#    Installed Xorg_xcb_util_cursor_jll ───── v0.1.5+0
#    Installed Libtiff_jll ────────────────── v4.7.1+0
#    Installed Plots ──────────────────────── v1.40.19
#    Installed Expat_jll ──────────────────── v2.7.1+0
#    Installed Format ─────────────────────── v1.3.7
#    Installed Libffi_jll ─────────────────── v3.4.7+0
#    Installed ColorVectorSpace ───────────── v0.11.0
#    Installed libevdev_jll ───────────────── v1.13.4+0
#    Installed Xorg_libXrender_jll ────────── v0.9.12+0
#    Installed libinput_jll ───────────────── v1.28.1+0
#    Installed OrderedCollections ─────────── v1.8.1
#    Installed Ogg_jll ────────────────────── v1.3.6+0
#    Installed Xorg_libXi_jll ─────────────── v1.8.3+0
#    Installed Vulkan_Loader_jll ──────────── v1.3.243+0
#    Installed Qt6ShaderTools_jll ─────────── v6.8.2+1
#    Installed Reexport ───────────────────── v1.2.2
#    Installed Qt6Declarative_jll ─────────── v6.8.2+1
#    Installed AliasTables ────────────────── v1.1.3
#    Installed LogExpFunctions ────────────── v0.3.29
#    Installed Xorg_libXcursor_jll ────────── v1.2.4+0
#    Installed MacroTools ─────────────────── v0.5.16
#    Installed Libuuid_jll ────────────────── v2.41.1+0
#    Installed Xorg_xcb_util_renderutil_jll ─ v0.3.10+0
#    Installed Xorg_libICE_jll ────────────── v1.1.2+0
#    Installed DocStringExtensions ────────── v0.9.5
#    Installed StableRNGs ─────────────────── v1.0.3
#    Installed Pixman_jll ─────────────────── v0.44.2+0
#    Installed libass_jll ─────────────────── v0.17.4+0
#    Installed Graphite2_jll ──────────────── v1.3.15+0
#    Installed Wayland_jll ────────────────── v1.24.0+0
#    Installed Xorg_xtrans_jll ────────────── v1.6.0+0
#    Installed Xorg_xkeyboard_config_jll ──── v2.44.0+0
#    Installed FFMPEG_jll ─────────────────── v7.1.1+0
#    Installed DataAPI ────────────────────── v1.16.0
#    Installed OpenSSL_jll ────────────────── v3.5.2+0
#    Installed BitFlags ───────────────────── v0.1.9
#    Installed LLVMOpenMP_jll ─────────────── v18.1.8+0
#    Installed Xorg_libXrandr_jll ─────────── v1.5.5+0
#    Installed FixedPointNumbers ──────────── v0.8.5
#    Installed Latexify ───────────────────── v0.16.9
#    Installed Xorg_libXfixes_jll ─────────── v6.0.1+0
#    Installed RecipesBase ────────────────── v1.3.4
#    Installed LAME_jll ───────────────────── v3.100.3+0
#    Installed Libiconv_jll ───────────────── v1.18.0+0
#    Installed Qt6Wayland_jll ─────────────── v6.8.2+1
#    Installed GettextRuntime_jll ─────────── v0.22.4+0
#    Installed Qt6Base_jll ────────────────── v6.8.2+1
#    Installed URIs ───────────────────────── v1.6.1
#    Installed LaTeXStrings ───────────────── v1.4.0
#    Installed Glib_jll ───────────────────── v2.84.3+0
#    Installed libvorbis_jll ──────────────── v1.3.8+0
#    Installed Libglvnd_jll ───────────────── v1.7.1+1
#    Installed Requires ───────────────────── v1.3.1
#    Installed Xorg_libX11_jll ────────────── v1.8.12+0
#    Installed Xorg_libXdmcp_jll ──────────── v1.1.6+0
#    Installed Unzip ──────────────────────── v0.2.0
#    Installed UnitfulLatexify ────────────── v1.7.0
#    Installed SortingAlgorithms ──────────── v1.2.2
#     Updating `C:\Users\User\.julia\environments\v1.11\Project.toml`
#   [91a5bcdd] + Plots v1.40.19
#     Updating `C:\Users\User\.julia\environments\v1.11\Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [d1d4a3ce] + BitFlags v0.1.9
#   [944b1d66] + CodecZlib v0.7.8
#   [35d6a980] + ColorSchemes v3.30.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [d38c429a] + Contour v0.6.3
#   [9a962f9c] + DataAPI v1.16.0
#   [864edb3b] + DataStructures v0.19.0
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [ffbed154] + DocStringExtensions v0.9.5
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [c87230d0] + FFMPEG v0.4.4
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [1fa38f19] + Format v1.3.7
#   [28b8d3ca] + GR v0.73.17
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.10.17
#   [92d709cd] + IrrationalConstants v0.2.4
#   [1019f520] + JLFzf v0.1.11
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [23fbe1c1] + Latexify v0.16.9
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [e6f89c97] + LoggingExtras v1.1.0
#   [1914dd2f] + MacroTools v0.5.16
#   [739be429] + MbedTLS v1.1.9
#   [442fdcdd] + Measures v0.3.2
#   [e1d29d7a] + Missings v1.2.0
#   [77ba4419] + NaNMath v1.1.3
#   [4d8831e6] + OpenSSL v1.5.0
#   [bac558e1] + OrderedCollections v1.8.1
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.3
#   [91a5bcdd] + Plots v1.40.19
#   [43287f4e] + PtrArrays v1.3.0
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [189a3867] + Reexport v1.2.2
#   [05181044] + RelocatableFolders v1.0.1
#   [ae029012] + Requires v1.3.1
#   [6c6a2e73] + Scratch v1.3.0
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [a2af1166] + SortingAlgorithms v1.2.2
#   [860ef19b] + StableRNGs v1.0.3
#   [10745b16] + Statistics v1.11.1
#   [82ae8749] + StatsAPI v1.7.1
#   [2913bbd2] + StatsBase v0.34.6
#   [62fd8b95] + TensorCore v0.1.1
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [5c2747f8] + URIs v1.6.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [1986cc42] + Unitful v1.24.0
#   [45397f5d] + UnitfulLatexify v1.7.0
#   [41fe7b60] + Unzip v0.2.0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [83423d85] + Cairo_jll v1.18.5+0
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.7.1+0
#   [b22a6f82] + FFMPEG_jll v7.1.1+0
#   [a3f928ae] + Fontconfig_jll v2.17.1+0
#   [d7e528f0] + FreeType2_jll v2.13.4+0
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.0+2
#   [d2c73de3] + GR_jll v0.73.17+0
#   [b0724c58] + GettextRuntime_jll v0.22.4+0
#   [7746bdde] + Glib_jll v2.84.3+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.1+0
#   [aacddb02] + JpegTurbo_jll v3.1.2+0
#   [c1c5ebd0] + LAME_jll v3.100.3+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.8+0
#   [dd4b983a] + LZO_jll v2.10.3+0
#   [e9f186c6] + Libffi_jll v3.4.7+0
#   [7e76a0d4] + Libglvnd_jll v1.7.1+1
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.41.1+0
#   [89763e89] + Libtiff_jll v4.7.1+0
#   [38a345b3] + Libuuid_jll v2.41.1+0
#   [e7412a2a] + Ogg_jll v1.3.6+0
#   [458c3c95] + OpenSSL_jll v3.5.2+0
#   [91d4177d] + Opus_jll v1.5.2+0
#   [36c8627f] + Pango_jll v1.56.3+0
# ⌅ [30392449] + Pixman_jll v0.44.2+0
#   [c0090381] + Qt6Base_jll v6.8.2+1
#   [629bc702] + Qt6Declarative_jll v6.8.2+1
#   [ce943373] + Qt6ShaderTools_jll v6.8.2+1
#   [e99dba38] + Qt6Wayland_jll v6.8.2+1
#   [a44049a8] + Vulkan_Loader_jll v1.3.243+0
#   [a2964d1f] + Wayland_jll v1.24.0+0
#   [ffd25f8a] + XZ_jll v5.8.1+0
#   [f67eecfb] + Xorg_libICE_jll v1.1.2+0
#   [c834827a] + Xorg_libSM_jll v1.2.6+0
#   [4f6342f7] + Xorg_libX11_jll v1.8.12+0
#   [0c0b7dd1] + Xorg_libXau_jll v1.0.13+0
#   [935fb764] + Xorg_libXcursor_jll v1.2.4+0
#   [a3789734] + Xorg_libXdmcp_jll v1.1.6+0
#   [1082639a] + Xorg_libXext_jll v1.3.7+0
#   [d091e8ba] + Xorg_libXfixes_jll v6.0.1+0
#   [a51aa0fd] + Xorg_libXi_jll v1.8.3+0
#   [d1454406] + Xorg_libXinerama_jll v1.1.6+0
#   [ec84b674] + Xorg_libXrandr_jll v1.5.5+0
#   [ea2f1a96] + Xorg_libXrender_jll v0.9.12+0
#   [c7cfdc94] + Xorg_libxcb_jll v1.17.1+0
#   [cc61e674] + Xorg_libxkbfile_jll v1.1.3+0
#   [e920d4aa] + Xorg_xcb_util_cursor_jll v0.1.5+0
#   [12413925] + Xorg_xcb_util_image_jll v0.4.1+0
#   [2def613f] + Xorg_xcb_util_jll v0.4.1+0
#   [975044d2] + Xorg_xcb_util_keysyms_jll v0.4.1+0
#   [0d47668e] + Xorg_xcb_util_renderutil_jll v0.3.10+0
#   [c22f9ab0] + Xorg_xcb_util_wm_jll v0.4.2+0
#   [35661453] + Xorg_xkbcomp_jll v1.4.7+0
#   [33bec58e] + Xorg_xkeyboard_config_jll v2.44.0+0
#   [c5fb5394] + Xorg_xtrans_jll v1.6.0+0
#   [3161d3a3] + Zstd_jll v1.5.7+1
#   [35ca27e7] + eudev_jll v3.2.14+0
#   [214eeab7] + fzf_jll v0.61.1+0
#   [a4ae2306] + libaom_jll v3.12.1+0
#   [0ac62f75] + libass_jll v0.17.4+0
#   [1183f4f0] + libdecor_jll v0.2.2+0
#   [2db6ffa8] + libevdev_jll v1.13.4+0
#   [f638f0a6] + libfdk_aac_jll v2.0.4+0
#   [36db933b] + libinput_jll v1.28.1+0
#   [b53b4c65] + libpng_jll v1.6.50+0
#   [f27f6e37] + libvorbis_jll v1.3.8+0
#   [009596ad] + mtdev_jll v1.1.7+0
#   [1270edf5] + x264_jll v10164.0.1+0
#   [dfaa095f] + x265_jll v4.1.0+0
#   [d8fb68d0] + xkbcommon_jll v1.9.2+0
#   [37e2e46d] + LinearAlgebra v1.11.0
#   [9e88b42a] + Serialization v1.11.0
#   [2f01184e] + SparseArrays v1.11.0
#   [8dfed614] + Test v1.11.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [4536629a] + OpenBLAS_jll v0.3.27+1
#   [05823500] + OpenLibm_jll v0.8.5+0
#   [efcefdf7] + PCRE2_jll v10.42.0+1
#   [bea87d4a] + SuiteSparse_jll v7.7.0+0
#   [8e850b90] + libblastrampoline_jll v5.11.0+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#    1317.1 ms  ✓ LaTeXStrings
#    1252.0 ms  ✓ Contour
#    1292.7 ms  ✓ StatsAPI
#    1312.1 ms  ✓ TensorCore
#    1489.4 ms  ✓ Measures
#    2055.6 ms  ✓ Statistics
#    1127.3 ms  ✓ Reexport
#    2734.0 ms  ✓ Grisu
#    1862.7 ms  ✓ StableRNGs
#    1919.9 ms  ✓ Requires
#    1976.4 ms  ✓ OrderedCollections
#    3518.8 ms  ✓ Format
#    2048.6 ms  ✓ Unzip
#    1812.3 ms  ✓ DocStringExtensions
#    1093.8 ms  ✓ SimpleBufferStream
#    1074.0 ms  ✓ PtrArrays
#    2119.1 ms  ✓ URIs
#    1523.2 ms  ✓ NaNMath
#    1849.6 ms  ✓ TranscodingStreams
#    1635.0 ms  ✓ DelimitedFiles
#    1319.3 ms  ✓ DataAPI
#    1119.7 ms  ✓ BitFlags
#    2855.5 ms  ✓ IrrationalConstants
#    1379.5 ms  ✓ ConcurrentUtilities
#    6795.6 ms  ✓ MacroTools
#    1297.1 ms  ✓ Scratch
#    2020.6 ms  ✓ LoggingExtras
#    2454.7 ms  ✓ OpenSSL_jll
#    2857.5 ms  ✓ MbedTLS
#    2454.8 ms  ✓ Graphite2_jll
#    2519.6 ms  ✓ ExceptionUnwrapping
#    1857.8 ms  ✓ Libmount_jll
#    1623.6 ms  ✓ EpollShim_jll
#    1662.1 ms  ✓ Xorg_libICE_jll
#    2210.3 ms  ✓ LLVMOpenMP_jll
#    1733.7 ms  ✓ Xorg_libXau_jll
#    1799.2 ms  ✓ Bzip2_jll
#    1804.8 ms  ✓ libpng_jll
#    1674.0 ms  ✓ libfdk_aac_jll
#    1652.1 ms  ✓ LAME_jll
#    4738.5 ms  ✓ UnicodeFun
#    2059.4 ms  ✓ fzf_jll
#    2178.4 ms  ✓ mtdev_jll
#    2298.9 ms  ✓ LERC_jll
#    2238.8 ms  ✓ Ogg_jll
#    2149.9 ms  ✓ Xorg_libXdmcp_jll
#    2261.1 ms  ✓ XZ_jll
#    2311.5 ms  ✓ JpegTurbo_jll
#    2148.6 ms  ✓ x265_jll
#    1800.6 ms  ✓ Xorg_xtrans_jll
#    1854.0 ms  ✓ Expat_jll
#    2039.2 ms  ✓ x264_jll
#    1934.8 ms  ✓ libevdev_jll
#    2022.1 ms  ✓ libaom_jll
#    1983.2 ms  ✓ Opus_jll
#    2042.8 ms  ✓ Zstd_jll
#    2008.3 ms  ✓ LZO_jll
#    1780.0 ms  ✓ eudev_jll
#    1772.7 ms  ✓ Libuuid_jll
#    1886.7 ms  ✓ Libiconv_jll
#    1923.9 ms  ✓ Libffi_jll
#    1883.7 ms  ✓ FriBidi_jll
#    1574.2 ms  ✓ Showoff
#    2053.5 ms  ✓ AliasTables
#    1992.3 ms  ✓ Missings
#    2033.2 ms  ✓ CodecZlib
#    3967.5 ms  ✓ Statistics → SparseArraysExt
#    5009.0 ms  ✓ RecipesBase
#    1535.7 ms  ✓ LogExpFunctions
#    1306.6 ms  ✓ RelocatableFolders
#    2975.5 ms  ✓ Xorg_libSM_jll
#    5346.6 ms  ✓ DataStructures
#    7285.1 ms  ✓ FixedPointNumbers
#    3101.0 ms  ✓ OpenSSL
#    2769.4 ms  ✓ Pixman_jll
#    2925.5 ms  ✓ FreeType2_jll
#    1508.4 ms  ✓ Xorg_libxcb_jll
#    1512.9 ms  ✓ Dbus_jll
#    1752.1 ms  ✓ libvorbis_jll
#    3994.8 ms  ✓ JLFzf
#    1531.3 ms  ✓ libinput_jll
#    2048.1 ms  ✓ Libtiff_jll
#    1964.2 ms  ✓ GettextRuntime_jll
#    1374.4 ms  ✓ Wayland_jll
#    1365.8 ms  ✓ SortingAlgorithms
#    1267.0 ms  ✓ Xorg_xcb_util_jll
#    1248.0 ms  ✓ Xorg_libX11_jll
#    7307.7 ms  ✓ Latexify
#    2038.6 ms  ✓ Fontconfig_jll
#    1831.7 ms  ✓ Xorg_xcb_util_image_jll
#    2668.2 ms  ✓ Glib_jll
#    1783.8 ms  ✓ Xorg_xcb_util_keysyms_jll
#    1770.6 ms  ✓ Xorg_xcb_util_renderutil_jll
#    3672.1 ms  ✓ ColorTypes
#    1594.5 ms  ✓ Xorg_xcb_util_wm_jll
#    1340.7 ms  ✓ Xorg_libXfixes_jll
#    1409.1 ms  ✓ Xorg_libXext_jll
#    1501.8 ms  ✓ Xorg_libXrender_jll
#    1449.6 ms  ✓ Xorg_libxkbfile_jll
#    1430.3 ms  ✓ Xorg_xcb_util_cursor_jll
#    1661.5 ms  ✓ Latexify → SparseArraysExt
#    1388.6 ms  ✓ Xorg_libXi_jll
#    1741.3 ms  ✓ Xorg_libXinerama_jll
#    6357.5 ms  ✓ StatsBase
#    1704.4 ms  ✓ Libglvnd_jll
#    1867.7 ms  ✓ ColorTypes → StyledStringsExt
#    1392.8 ms  ✓ Xorg_libXcursor_jll
#    1554.5 ms  ✓ Xorg_libXrandr_jll
#    1528.3 ms  ✓ Xorg_xkbcomp_jll
#    2256.6 ms  ✓ Cairo_jll
#     846.7 ms  ✓ Xorg_xkeyboard_config_jll
#    5114.4 ms  ✓ ColorVectorSpace
#     840.7 ms  ✓ xkbcommon_jll
#    1183.3 ms  ✓ HarfBuzz_jll
#     858.1 ms  ✓ Vulkan_Loader_jll
#    1247.6 ms  ✓ libass_jll
#    1359.5 ms  ✓ Pango_jll
#     791.0 ms  ✓ libdecor_jll
#    2392.3 ms  ✓ Qt6Base_jll
#    1945.3 ms  ✓ FFMPEG_jll
#    1158.0 ms  ✓ GLFW_jll
#    1312.2 ms  ✓ Qt6ShaderTools_jll
#    1223.4 ms  ✓ FFMPEG
#    1743.4 ms  ✓ GR_jll
#    2814.6 ms  ✓ Qt6Declarative_jll
#   12851.9 ms  ✓ Colors
#     701.7 ms  ✓ Qt6Wayland_jll
#    5056.5 ms  ✓ ColorSchemes
#   50016.8 ms  ✓ Unitful
#     901.4 ms  ✓ Unitful → PrintfExt
#    1490.3 ms  ✓ UnitfulLatexify
#   39813.3 ms  ✓ HTTP
#   20079.5 ms  ✓ PlotUtils
#    5530.7 ms  ✓ GR
#    2847.2 ms  ✓ PlotThemes
#    4288.3 ms  ✓ RecipesPipeline
#   64857.0 ms  ✓ Plots
#    4639.7 ms  ✓ Plots → UnitfulExt
#    5235.3 ms  ✓ Plots → IJuliaExt
#   139 dependencies successfully precompiled in 145 seconds. 47 already precompiled.
#    Resolving package versions...
#     Updating `C:\Users\User\.julia\environments\v1.11\Project.toml`
#   [9a3f8284] + Random v1.11.0
#   No Changes to `C:\Users\User\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#    Installed HypergeometricFunctions ───── v0.3.28
#    Installed Rmath_jll ─────────────────── v0.5.1+0
#    Installed PDMats ────────────────────── v0.11.35
#    Installed StatsFuns ─────────────────── v1.5.0
#    Installed GLM ───────────────────────── v1.9.0
#    Installed StatsModels ───────────────── v0.7.6
#    Installed DataStructures ────────────── v0.18.22
#    Installed SpecialFunctions ──────────── v2.5.1
#    Installed Compat ────────────────────── v4.18.0
#    Installed DataValueInterfaces ───────── v1.0.0
#    Installed TableTraits ───────────────── v1.0.1
#    Installed OpenSpecFun_jll ───────────── v0.5.6+0
#    Installed Rmath ─────────────────────── v0.8.0
#    Installed Tables ────────────────────── v1.12.1
#    Installed IteratorInterfaceExtensions ─ v1.0.0
#    Installed FillArrays ────────────────── v1.13.0
#    Installed QuadGK ────────────────────── v2.11.2
#    Installed ShiftedArrays ─────────────── v2.0.0
#    Installed Distributions ─────────────── v0.25.120
#     Updating `C:\Users\User\.julia\environments\v1.11\Project.toml`
#   [38e38edf] + GLM v1.9.0
#     Updating `C:\Users\User\.julia\environments\v1.11\Manifest.toml`
#   [34da2185] + Compat v4.18.0
# ⌅ [864edb3b] ↓ DataStructures v0.19.0 ⇒ v0.18.22
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [31c24e10] + Distributions v0.25.120
#   [1a297f60] + FillArrays v1.13.0
#   [38e38edf] + GLM v1.9.0
#   [34004b35] + HypergeometricFunctions v0.3.28
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [90014a1f] + PDMats v0.11.35
#   [1fd47b50] + QuadGK v2.11.2
#   [79098fc4] + Rmath v0.8.0
#   [1277b4bf] + ShiftedArrays v2.0.0
#   [276daf66] + SpecialFunctions v2.5.1
#   [4c63d2b9] + StatsFuns v1.5.0
#   [3eaba693] + StatsModels v0.7.6
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.1
#   [efe28fd5] + OpenSpecFun_jll v0.5.6+0
#   [f50d1b31] + Rmath_jll v0.5.1+0
#   [4607b0f0] + SuiteSparse
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     903.5 ms  ✓ IteratorInterfaceExtensions
#     989.0 ms  ✓ DataValueInterfaces
#    1146.6 ms  ✓ ShiftedArrays
#    1564.2 ms  ✓ SuiteSparse
#     886.1 ms  ✓ TableTraits
#    1567.0 ms  ✓ Compat
#    1654.9 ms  ✓ OpenSpecFun_jll
#    1679.0 ms  ✓ Rmath_jll
#    2024.0 ms  ✓ FillArrays
#    1066.9 ms  ✓ Compat → CompatLinearAlgebraExt
#    1101.2 ms  ✓ FillArrays → FillArraysStatisticsExt
#    1986.0 ms  ✓ PDMats
#    2086.7 ms  ✓ Tables
#    1920.5 ms  ✓ FillArrays → FillArraysSparseArraysExt
#    2226.4 ms  ✓ Rmath
#     888.3 ms  ✓ FillArrays → FillArraysPDMatsExt
#    2404.5 ms  ✓ DataStructures
#     667.5 ms  ✓ SortingAlgorithms
#    4417.2 ms  ✓ SpecialFunctions
#    1173.2 ms  ✓ QuadGK
#     924.9 ms  ✓ ColorVectorSpace → SpecialFunctionsExt
#    1321.3 ms  ✓ HypergeometricFunctions
#    2348.1 ms  ✓ StatsBase
#    1682.6 ms  ✓ StatsFuns
#    2916.1 ms  ✓ StatsModels
#    5791.6 ms  ✓ Distributions
#    1506.6 ms  ✓ Distributions → DistributionsTestExt
#    2549.9 ms  ✓ GLM
#   67071.7 ms  ✓ Plots
#    4357.5 ms  ✓ Plots → UnitfulExt
#    4943.4 ms  ✓ Plots → IJuliaExt
#   31 dependencies successfully precompiled in 82 seconds. 180 already precompiled.
#    Resolving package versions...
#    Installed InlineStrings ────── v1.4.4
#    Installed InvertedIndices ──── v1.3.1
#    Installed PooledArrays ─────── v1.4.3
#    Installed SentinelArrays ───── v1.4.8
#    Installed Crayons ──────────── v4.1.1
#    Installed StringManipulation ─ v0.4.1
#    Installed PrettyTables ─────── v2.4.0
#    Installed DataFrames ───────── v1.7.0
#     Updating `C:\Users\User\.julia\environments\v1.11\Project.toml`
#   [a93c6f00] + DataFrames v1.7.0
#     Updating `C:\Users\User\.julia\environments\v1.11\Manifest.toml`
#   [a8cc5b0e] + Crayons v4.1.1
#   [a93c6f00] + DataFrames v1.7.0
#   [842dd82b] + InlineStrings v1.4.4
#   [41ab1584] + InvertedIndices v1.3.1
#   [2dfb63ee] + PooledArrays v1.4.3
#   [08abe8d2] + PrettyTables v2.4.0
#   [91c51154] + SentinelArrays v1.4.8
#   [892a3eda] + StringManipulation v0.4.1
#   [9fa8497b] + Future v1.11.0
# Precompiling project...
#    1375.1 ms  ✓ InvertedIndices
#    1795.9 ms  ✓ InlineStrings
#    1528.2 ms  ✓ PooledArrays
#    2177.1 ms  ✓ Crayons
#    2153.4 ms  ✓ SentinelArrays
#    2708.8 ms  ✓ StringManipulation
#     747.3 ms  ✓ InlineStrings → ParsersExt
#   17467.5 ms  ✓ PrettyTables
#   40931.2 ms  ✓ DataFrames
#    1193.2 ms  ✓ Latexify → DataFramesExt
#   10 dependencies successfully precompiled in 64 seconds. 212 already precompiled.
#    Resolving package versions...
#     Updating `C:\Users\User\.julia\environments\v1.11\Project.toml`
#   [b964fa9f] + LaTeXStrings v1.4.0
#   No Changes to `C:\Users\User\.julia\environments\v1.11\Manifest.toml`
# ParseError:
# # Error @ ]8;;file://C:/Users/User/Desktop/CausalAI-Course/Labs/PD/PD2/In[1]#9:26\In[1]:9:26]8;;\
# Pkg.add("LaTeXStrings")
# Pkg.add("Statistics")  =#
# #                        └ ── premature end of input
#
# Stacktrace:
#  [1] top-level scope
#    @ In[1]:9

# %% [markdown]
# ## 1. Fitting polinomial predictors to data

# %%
using Plots
using Random
using GLM
using DataFrames
using LaTeXStrings
using Statistics
using StatsBase
# Out:
# ArgumentError: Package StatsBase not found in current path.
# - Run `import Pkg; Pkg.add("StatsBase")` to install the StatsBase package.
#
# Stacktrace:
#  [1] macro expansion
#    @ .\loading.jl:2296 [inlined]
#  [2] macro expansion
#    @ .\lock.jl:273 [inlined]
#  [3] __require(into::Module, mod::Symbol)
#    @ Base .\loading.jl:2271
#  [4] #invoke_in_world#3
#    @ .\essentials.jl:1089 [inlined]
#  [5] invoke_in_world
#    @ .\essentials.jl:1086 [inlined]
#  [6] require(into::Module, mod::Symbol)
#    @ Base .\loading.jl:2260

# %% [markdown]
# ### First, we generate the features and noise randomly as we did previously

# %%
W = rand(Float64,1000);
W = sort(W);
W
# Out:
# 1000-element Vector{Float64}:
#  0.00016233161646528327
#  0.0002555614121437788
#  0.0009513046653015778
#  0.0014368260746265848
#  0.002844465618608849
#  0.004220855436262383
#  0.004612439891580222
#  0.0074437140943204305
#  0.008866405335263394
#  0.010094263326976272
#  0.011537791573376421
#  0.011735466386945559
#  0.012153067311637122
#  ⋮
#  0.9933992929803988
#  0.9941379684680823
#  0.9949348484711811
#  0.9951056863701089
#  0.9956765953760527
#  0.9958934417682771
#  0.9969529037525838
#  0.9972780547584619
#  0.9977933820390803
#  0.9978028954153756
#  0.9979683262774331
#  0.9988883710593697

# %%
e = randn(1000);
e
# Out:
# 1000-element Vector{Float64}:
#  -1.8831744279375147
#   0.9266819263640075
#   0.5398040291620605
#  -0.8361324661950186
#  -0.31422032865253935
#   1.4181484096856025
#  -0.9110928038607784
#  -0.9770665672535984
#  -1.0302990476353853
#   0.6368076144680714
#   0.7325068465995642
#  -2.328188678821147
#   0.33240947974306406
#   ⋮
#  -1.5790703609835588
#   0.6875413073069602
#   1.0316120445643364
#  -0.8716336863229314
#   0.2407560927000398
#  -0.4883347611551725
#  -0.4347946169198937
#   1.965951510692113
#   0.13516552226114653
#  -1.5384089874068618
#  -0.4621209284169979
#  -0.5504229595107331

# %% [markdown]
# ### Then, construct the dependent variable

# %%
y = exp.(4W) + e;

# %% [markdown]
# ### As in R, it is preferred to store the variables in a dataframe because this structure is an argument of the  model estimation function.

# %%
data = DataFrame([y;;W],["y","W"])
# Out:
# 1000×2 DataFrame
#   Row │ y            W
#       │ Float64      Float64
# ──────┼──────────────────────────
#     1 │ -0.882525    0.000162332
#     2 │  1.9277      0.000255561
#     3 │  1.54362     0.000951305
#     4 │  0.169631    0.00143683
#     5 │  0.697223    0.00284447
#     6 │  2.43518     0.00422086
#     7 │  0.107528    0.00461244
#     8 │  0.053156    0.00744371
#     9 │  0.00580298  0.00886641
#    10 │  1.67801     0.0100943
#    11 │  1.77974     0.0115378
#   ⋮   │      ⋮            ⋮
#   991 │ 54.5347      0.994935
#   992 │ 52.668       0.995106
#   993 │ 53.9028      0.995677
#   994 │ 53.2203      0.995893
#   995 │ 53.5019      0.996953
#   996 │ 55.9729      0.997278
#   997 │ 54.2535      0.997793
#   998 │ 52.582       0.997803
#   999 │ 53.6941      0.997968
#  1000 │ 53.8055      0.998888
#                  979 rows omitted

# %% [markdown]
# ### Now we proceed to fit the model. The function to do that is pretty similar to the one in R

# %%
model = lm(@formula(y~W),data)
y_hat = predict(model,select(data,"W"));

# %% [markdown]
# ### The plot of the fitting line looks like this

# %%
scatter(W,y, label = false,  ms=2)
plot!(W,y_hat, label = false, lc=:red)
xlabel!(L"W_i")
ylabel!(L"Y_i")
title!(L"p=2")

# %% [markdown]
# ### Next, we fit a cuadratic curve to the data

# %%
W_2 = [W;; W.^2]
data = DataFrame([y;;W_2],["y","W","W2"])
# Out:
# 1000×3 DataFrame
#   Row │ y            W            W2
#       │ Float64      Float64      Float64
# ──────┼───────────────────────────────────────
#     1 │ -0.882525    0.000162332  2.63516e-8
#     2 │  1.9277      0.000255561  6.53116e-8
#     3 │  1.54362     0.000951305  9.04981e-7
#     4 │  0.169631    0.00143683   2.06447e-6
#     5 │  0.697223    0.00284447   8.09098e-6
#     6 │  2.43518     0.00422086   1.78156e-5
#     7 │  0.107528    0.00461244   2.12746e-5
#     8 │  0.053156    0.00744371   5.54089e-5
#     9 │  0.00580298  0.00886641   7.86131e-5
#    10 │  1.67801     0.0100943    0.000101894
#    11 │  1.77974     0.0115378    0.000133121
#   ⋮   │      ⋮            ⋮            ⋮
#   991 │ 54.5347      0.994935     0.989895
#   992 │ 52.668       0.995106     0.990235
#   993 │ 53.9028      0.995677     0.991372
#   994 │ 53.2203      0.995893     0.991804
#   995 │ 53.5019      0.996953     0.993915
#   996 │ 55.9729      0.997278     0.994564
#   997 │ 54.2535      0.997793     0.995592
#   998 │ 52.582       0.997803     0.995611
#   999 │ 53.6941      0.997968     0.995941
#  1000 │ 53.8055      0.998888     0.997778
#                               979 rows omitted

# %%
model = lm(@formula(y~ W + W^2),data)
y_hat = predict(model,select(data,["W","W2"]));

# %% [markdown]
# ### And plot the fitting curve

# %%
scatter(W,y, label = false,  ms=2)
plot!(W,y_hat, label = false, lc=:red)
xlabel!(L"W_i")
ylabel!(L"Y_i")
title!(L"p=3")

# %% [markdown]
# ### Finally, we fit a cubic curve to the data

# %%
W_3 = [W_2;; W.^3]
data = DataFrame([y;;W_3],["y","W","W2","W3"])
# Out:
# 1000×4 DataFrame
#   Row │ y            W            W2           W3
#       │ Float64      Float64      Float64      Float64
# ──────┼────────────────────────────────────────────────────
#     1 │ -0.882525    0.000162332  2.63516e-8   4.27769e-12
#     2 │  1.9277      0.000255561  6.53116e-8   1.66911e-11
#     3 │  1.54362     0.000951305  9.04981e-7   8.60912e-10
#     4 │  0.169631    0.00143683   2.06447e-6   2.96628e-9
#     5 │  0.697223    0.00284447   8.09098e-6   2.30145e-8
#     6 │  2.43518     0.00422086   1.78156e-5   7.51972e-8
#     7 │  0.107528    0.00461244   2.12746e-5   9.81278e-8
#     8 │  0.053156    0.00744371   5.54089e-5   4.12448e-7
#     9 │  0.00580298  0.00886641   7.86131e-5   6.97016e-7
#    10 │  1.67801     0.0100943    0.000101894  1.02855e-6
#    11 │  1.77974     0.0115378    0.000133121  1.53592e-6
#   ⋮   │      ⋮            ⋮            ⋮            ⋮
#   991 │ 54.5347      0.994935     0.989895     0.984881
#   992 │ 52.668       0.995106     0.990235     0.985389
#   993 │ 53.9028      0.995677     0.991372     0.987086
#   994 │ 53.2203      0.995893     0.991804     0.987731
#   995 │ 53.5019      0.996953     0.993915     0.990887
#   996 │ 55.9729      0.997278     0.994564     0.991856
#   997 │ 54.2535      0.997793     0.995592     0.993395
#   998 │ 52.582       0.997803     0.995611     0.993423
#   999 │ 53.6941      0.997968     0.995941     0.993917
#  1000 │ 53.8055      0.998888     0.997778     0.996669
#                                            979 rows omitted

# %%
model = lm(@formula(y~ W + W2 + W3),data)
y_hat = predict(model,select(data,["W","W2","W3"]));

# %% [markdown]
# ### And plot the results

# %%
scatter(W,y, label = false,  ms=2)
plot!(W,y_hat, label = false, lc=:red)
xlabel!(L"W_i")
ylabel!(L"Y_i")
title!(L"p=4")

# %% [markdown]
# ## 2. Overfitting

# %% [markdown]
# ### As we did in R and Python, we first study the case where $p=n=1000$, so now we create the features and dependen variable randomly

# %%
X = randn(1000,1000-1);
y = randn(1000);
print(size(X)) 
print(size(y))
# Out:
# (1000, 999)(1000,)

# %%
data = DataFrame([y;;X],:auto)
rename!(data, :x1 => :y)
# Out:
# 1000×1000 DataFrame
#   Row │ y           x2          x3          x4          x5          x6         ⋯
#       │ Float64     Float64     Float64     Float64     Float64     Float64    ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ -1.84348    -0.492954    0.912158   -0.527138    0.987874    0.840219  ⋯
#     2 │  0.35633     0.113169   -0.0694922  -0.639868    0.0234713   0.980017
#     3 │ -1.45132     0.589612    0.723965   -1.09506    -1.49172     0.309042
#     4 │ -0.287835    0.334976    0.860307    0.412845    1.0646     -1.39319
#     5 │  2.40953     0.712319    1.32484    -1.28876     0.295156    0.268418  ⋯
#     6 │ -0.350438   -1.72811     0.281243    0.524917   -1.85178     0.0382255
#     7 │ -1.02922     0.216604   -0.566258   -0.662638   -1.6864     -2.08422
#     8 │ -0.592686   -1.86705    -0.315277   -0.31883     0.750265    1.50913
#     9 │  0.395411    0.670917   -0.411981   -0.754431    0.392746    1.37191   ⋯
#    10 │ -0.600665    0.138069   -1.36517     0.976594    1.00288    -0.0481635
#    11 │ -0.250738   -1.12972     1.10715     0.561384    0.0781473  -1.08476
#   ⋮   │     ⋮           ⋮           ⋮           ⋮           ⋮           ⋮      ⋱
#   991 │ -1.12752    -0.381128    0.850567   -0.538658   -0.563329    0.554336
#   992 │  1.00873     0.174245   -2.42296     0.343584    1.71427    -0.0726198 ⋯
#   993 │  0.180246   -0.101041    1.21823    -0.370916   -1.49221    -1.08556
#   994 │  1.20083     1.80367    -1.46126     0.933363    0.163457    2.32317
#   995 │ -0.311616    0.758434    0.797287   -0.6327      2.44424    -1.09433
#   996 │ -1.15342     0.908844    1.49012    -1.30559     0.50743     0.030783  ⋯
#   997 │ -0.260766   -0.0112121   0.477408   -0.583767    1.81696     0.0190825
#   998 │ -1.06187    -0.221373   -0.956632    0.624641    0.911674   -0.56155
#   999 │  1.77463     1.38132     0.11935    -0.949281    0.33421    -1.50029
#  1000 │  0.354451    1.11615     0.042726    0.881549   -1.39776    -0.587114  ⋯
#                                                 994 columns and 979 rows omitted

# %% [markdown]
# ### In Julia's "lm" function, there is not an integrated command to regress the dependent variable on all the features. And we need it because there are 999 features + constant. So, we sort this problem out with a function called "term"

# %%
covariates = names(data)[2:end]
model = lm(term(:y) ~ sum(term.(covariates)), data);

# %% [markdown]
# ### And now we calculate the MSE

# %%
mse = mean((y-predict(model,select(data,covariates))).^2)
# Out:
# 1.2274243809413115e-23

# %% [markdown]
# ### and the R-squared

# %%
R_sq = 1 - mse / mean((y.-mean(y)).^2)
# Out:
# 1.0

# %% [markdown]
# ### Then we study the case where $p=\frac{n}{2}=500$

# %%
X = randn(1000,500-1);
data = DataFrame([y;;X],:auto)
rename!(data, :x1 => :y)
# Out:
# 1000×500 DataFrame
#   Row │ y           x2          x3           x4          x5          x6        ⋯
#       │ Float64     Float64     Float64      Float64     Float64     Float64   ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ -1.84348     1.2185      0.561204     0.622829   -0.278527    0.46031  ⋯
#     2 │  0.35633    -0.72591    -0.690794     0.759139    0.0764527   0.688894
#     3 │ -1.45132     1.44063    -0.471261    -0.461248   -2.816       1.9347
#     4 │ -0.287835    0.171165   -0.00700337   0.193044   -0.769154   -0.031065
#     5 │  2.40953    -0.27134    -1.1427      -0.307629    1.38801    -0.08081  ⋯
#     6 │ -0.350438   -0.0968648  -1.38446     -0.0750808  -0.409752    0.055940
#     7 │ -1.02922    -0.931467    0.961751    -0.320316    1.18032     0.938707
#     8 │ -0.592686   -1.20247     0.455935     0.759743    0.542284   -1.0605
#     9 │  0.395411    0.364124    0.106001    -1.0946      1.56848     1.9282   ⋯
#    10 │ -0.600665    0.142962    0.911923     0.794348    0.468075    0.475528
#    11 │ -0.250738   -0.0262765  -1.33637      0.0882552  -0.90708    -0.597666
#   ⋮   │     ⋮           ⋮            ⋮           ⋮           ⋮           ⋮     ⋱
#   991 │ -1.12752     0.395616    0.555799    -1.24439     0.411337    0.871141
#   992 │  1.00873     2.2038      0.542045     2.94616    -0.190309   -0.164506 ⋯
#   993 │  0.180246    0.508969   -0.279669    -0.279726   -0.472624   -1.05107
#   994 │  1.20083     0.238159    0.305467    -1.6616      0.820128   -0.062969
#   995 │ -0.311616   -0.148726   -2.4721      -0.21512    -0.106171   -0.273537
#   996 │ -1.15342     0.359032    0.273849     0.249846   -0.33911    -0.828651 ⋯
#   997 │ -0.260766    0.0951539   1.58284     -0.939593    1.44769    -1.7112
#   998 │ -1.06187    -2.35102    -0.726536     1.40379     0.725295   -0.644876
#   999 │  1.77463    -0.692004    1.3478      -0.348158    1.65325    -0.516529
#  1000 │  0.354451   -0.280258    0.634393     1.18699    -0.897929   -1.3575   ⋯
#                                                 495 columns and 979 rows omitted

# %% [markdown]
# ### We fit the model

# %%
covariates = names(data)[2:end]
model = lm(term(:y) ~ sum(term.(covariates)), data);

# %% [markdown]
# ### Calculate the MSE

# %%
mse = mean((y-predict(model,select(data,covariates))).^2)
# Out:
# 0.48860917192640985

# %% [markdown]
# ### The R-squared

# %%
R_sq = 1 - mse / mean((y.-mean(y)).^2)
# Out:
# 0.5123143978192065

# %% [markdown]
# ### And the adjusted R-squared

# %%
adj_mse = 1000/500*mse
adjR_sq = 1 - adj_mse / mean((y.-mean(y)).^2)
adjR_sq
# Out:
# 0.024628795638413026

# %% [markdown]
# ### Finally, we study the case where $p=\frac{n}{20}=50$

# %%
X = randn(1000,50-1);
data = DataFrame([y;;X],:auto)
rename!(data, :x1 => :y)
# Out:
# 1000×50 DataFrame
#   Row │ y           x2          x3          x4          x5          x6         ⋯
#       │ Float64     Float64     Float64     Float64     Float64     Float64    ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ -1.84348     1.28162     0.853794    1.01454     1.28627    -0.100678  ⋯
#     2 │  0.35633    -0.750004   -2.38714    -0.316943   -1.16468    -0.627315
#     3 │ -1.45132     0.592751    1.43808    -1.30178    -1.61451    -0.120409
#     4 │ -0.287835    1.47198     0.532527   -0.37834    -0.415579   -0.705627
#     5 │  2.40953     0.0962719   0.0999752   0.42225    -2.38789    -2.09734   ⋯
#     6 │ -0.350438   -1.11939    -1.28249    -0.554846    1.97298     0.751889
#     7 │ -1.02922    -1.5749      0.832794    0.448266   -1.02893    -0.292244
#     8 │ -0.592686   -0.119832   -1.84311     0.181637   -1.01056     0.668177
#     9 │  0.395411   -1.20324     0.776157   -0.548672   -1.59848     1.247     ⋯
#    10 │ -0.600665   -0.491381    1.44469    -0.699972   -0.0600885   0.462123
#    11 │ -0.250738    1.17076    -0.546201   -2.09979    -0.674565    0.278457
#   ⋮   │     ⋮           ⋮           ⋮           ⋮           ⋮           ⋮      ⋱
#   991 │ -1.12752    -0.206295   -1.49568     0.184902   -0.398972   -1.36842
#   992 │  1.00873    -1.04098     0.209513   -0.258807    1.61319     1.60042   ⋯
#   993 │  0.180246   -1.03956     0.280962    0.11825     1.51283     0.572499
#   994 │  1.20083    -1.28637    -0.277674   -0.55459     0.764865   -1.27248
#   995 │ -0.311616    0.871422    0.809339    0.271288    1.3101      1.61975
#   996 │ -1.15342    -0.684888    0.0717198   1.27835     1.37088     0.827794  ⋯
#   997 │ -0.260766    0.279016   -0.460943   -1.09818    -0.692694   -0.726208
#   998 │ -1.06187    -0.459842   -0.0378023  -0.486577    0.39131     0.316627
#   999 │  1.77463    -0.217863    0.637388   -0.122238    0.182747    0.384661
#  1000 │  0.354451    0.0514329  -0.735406   -0.843175    0.435338   -2.90432   ⋯
#                                                  44 columns and 979 rows omitted

# %%
covariates = names(data)[2:end]
model = lm(term(:y) ~ sum(term.(covariates)), data);

# %% [markdown]
# ### Calculate the MSE

# %%
mse = mean((y-predict(model,select(data,covariates))).^2)
# Out:
# 0.9560984296078561

# %% [markdown]
# ### R-squared

# %%
R_sq = 1 - mse / mean((y.-mean(y)).^2)
# Out:
# 0.04570878899169606

# %% [markdown]
# ### And adjusted R-squared

# %%
adj_mse = 1000/500*mse
adjR_sq = 1 - adj_mse / mean((y.-mean(y)).^2)
adjR_sq
# Out:
# -0.9085824220166079

# %% [markdown]
# ## 3. Data splitting

# %% [markdown]
# ### In the final section, we perform data splitting in Julia. As we did previously, we will work with the data generating process of section 1.

# %%
# Features

W = rand(Float64,1000);
W = sort(W);

# Noise

e = randn(1000);

# Dependent variable

y = exp.(4W) + e;

# %% [markdown]
# ### Now we store all the data in dataframes

# %%
W_1 = W;
W_2 = [W;; W.^2];
W_3 = sin.(W);

data_1 = DataFrame([y;;W_1],["y", "W"]);
data_2 = DataFrame([y;;W_2],["y", "W", "W2"]);
data_3 = DataFrame([y;;W_3],["y", "sinW"]);

# %% [markdown]
# ### In this case, we are going to build our data splitter. Our data splitter is going to work as follows: we will input the dataframe and the proportion ($\alpha$) of the data that we want for training. Given those arguments, we will sample $\alpha n$ indexes of the dataset randomly without replacement, and keep the observations with those indexes. That will be our training sample. Then, we will select the remaining data as test sample.

# %%
function datasplitting(data,proportion)

    sampling = sample([1:size(data,1);],Int(proportion*size(data,1)),replace=false) #sample indexes
    sampling = sort(sampling) # sort index
    train = data[sampling,:] # subset of dataframe with sampled indexes -> train set
    remaining = [i for i in 1:size(data,1) if isempty(searchsorted(sampling, i))] #remaining indexes of the data frame
    test = data[remaining, :] #s ubset of dataframe with remaining indexes -> test set

    return train, test
end
# Out:
# datasplitting (generic function with 1 method)

# %% [markdown]
# ### With the built function, we apply it to the three datasets

# %%
train_1, test_1 = datasplitting(data_1,0.75);
train_2, test_2 = datasplitting(data_2,0.75);
train_3, test_3 = datasplitting(data_3,0.75);
# Out:
# UndefVarError: `sample` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
# Hint: a global variable of this name may be made accessible by importing AliasTables in the current active module Main
# Hint: a global variable of this name may be made accessible by importing StatsBase in the current active module Main
#
# Stacktrace:
#  [1] datasplitting(data::DataFrame, proportion::Float64)
#    @ Main .\In[34]:3
#  [2] top-level scope
#    @ In[35]:1

# %% [markdown]
# ### Fit the model with each training sample

# %%
model_1 = lm(@formula(y~W), train_1);
model_2 = lm(@formula(y~W+W2), train_2);
model_3 = lm(@formula(y~ sinW), train_3);
# Out:
# UndefVarError: `train_1` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[36]:1

# %% [markdown]
# ### Build auxiliar variables to calculate goodness of fit measures

# %%
y_1_test = test_1[:,"y"];
y_2_test = test_2[:,"y"];
y_3_test = test_3[:,"y"];
# Out:
# UndefVarError: `test_1` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[37]:1

# %%
y_1_hat_test = predict(model_1,select(test_1,"W"));
y_2_hat_test = predict(model_2,select(test_2,["W","W2"]));
y_3_hat_test = predict(model_3,select(test_3,"sinW"));

# %%
mse_1_test = mean((y_1_test - y_1_hat_test).^2)
mse_2_test = mean((y_2_test - y_2_hat_test).^2)
mse_3_test = mean((y_3_test - y_3_hat_test).^2)
# Out:
# 53.086697400369886

# %%
R_sq_1_test = 1 - mse_1_test/mean((y_1_test.-mean(y_1_test)).^2)
R_sq_2_test = 1 - mse_2_test/mean((y_2_test.-mean(y_2_test)).^2)
R_sq_3_test = 1 - mse_3_test/mean((y_3_test.-mean(y_3_test)).^2)
# Out:
# 0.7264881162878609

# %% [markdown]
# ### And calculate them

# %%
# MSE

mse_1_test = mean((y_1_test - y_1_hat_test).^2)
mse_2_test = mean((y_2_test - y_2_hat_test).^2)
mse_3_test = mean((y_3_test - y_3_hat_test).^2)

println("MSE out of sample of predictor 1 is $mse_1_test")
println("MSE out of sample of predictor 2 is $mse_2_test")
println("MSE out of sample of predictor 3 is $mse_3_test")

# R-squared

R_sq_1_test = 1 - mse_1_test/mean((y_1_test.-mean(y_1_test)).^2)
R_sq_2_test = 1 - mse_2_test/mean((y_2_test.-mean(y_2_test)).^2)
R_sq_3_test = 1 - mse_3_test/mean((y_3_test.-mean(y_3_test)).^2)

println("R-squared out of sample of predictor 1 is $R_sq_1_test")
println("R-squared out of sample of predictor 2 is $R_sq_2_test")
println("R-squared out of sample of predictor 3 is $R_sq_3_test")

# Adjusted R-squared

adj_mse_1_test = 250 / (250-2) * mse_1_test
adjR_sq_1_test = 1 - adj_mse_1_test / mean((y_1_test.-mean(y_1_test)).^2)

adj_mse_2_test = 250 / (250-3) * mse_2_test
adjR_sq_2_test = 1 - adj_mse_2_test / mean((y_2_test.-mean(y_2_test)).^2)

adj_mse_3_test = 250 / (250-2) * mse_3_test
adjR_sq_3_test = 1 - adj_mse_3_test / mean((y_3_test.-mean(y_3_test)).^2)

println("Adjusted R-squared out of sample of predictor 1 is $adjR_sq_1_test")
println("Adjusted R-squared out of sample of predictor 2 is $adjR_sq_2_test")
println("Adjusted R-squared out of sample of predictor 3 is $adjR_sq_3_test")
# Out:
# MSE out of sample of predictor 1 is 40.15346603003548
# MSE out of sample of predictor 2 is 3.832803619134921
# MSE out of sample of predictor 3 is 53.086697400369886
# R-squared out of sample of predictor 1 is 0.8073781467624106
# R-squared out of sample of predictor 2 is 0.9785395346511195
# R-squared out of sample of predictor 3 is 0.7264881162878609
# Adjusted R-squared out of sample of predictor 1 is 0.805824744720172
# Adjusted R-squared out of sample of predictor 2 is 0.9782788812258295
# Adjusted R-squared out of sample of predictor 3 is 0.7242823752901825
